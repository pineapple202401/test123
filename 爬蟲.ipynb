# %% [markdown]
# *   BeautifulSoup4 - https://beautiful-soup-4.readthedocs.io/en/latest/
# *   Requests - https://requests.readthedocs.io/en/latest/
# *   Pandas - https://pandas.pydata.org/

# %%
# !pip install BeautifulSoup4
# !pip install requests
# !pip install pandas
# Out:
# Requirement already satisfied: BeautifulSoup4 in /usr/local/lib/python3.10/dist-packages (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from BeautifulSoup4) (2.6)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (2.32.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests) (2024.7.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)

# %%
# 目標網址
base_url = 'https://www.ptt.cc/bbs/'


# 目標看板 (改成自己有興趣的看板)
target_board = 'Stock'


# 目標頁面
target_page = '/index'


# 目標頁面的頁數
page_num = ''


# 目標頁面的頁面的附屬檔名
html_ext = '.html'


# 合併完整路徑
target = base_url + target_board + target_page + page_num + html_ext
print(target)
# Out:
# https://www.ptt.cc/bbs/Stock/index.html

# %%
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36'
}
print(headers)
# Out:
# {'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36'}

# %%
import requests
data = requests.get(target, headers=headers)
print(data.content)
# Out:
# b'<!DOCTYPE html>\n<html>\n\t<head>\n\t\t<meta charset="utf-8">\n\t\t\n\n<meta name="viewport" content="width=device-width, initial-scale=1">\n\n<title>\xe7\x9c\x8b\xe6\x9d\xbf Stock \xe6\x96\x87\xe7\xab\xa0\xe5\x88\x97\xe8\xa1\xa8 - \xe6\x89\xb9\xe8\xb8\xa2\xe8\xb8\xa2\xe5\xaf\xa6\xe6\xa5\xad\xe5\x9d\x8a</title>\n\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-common.css">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-custom.css">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen">\n<link rel="stylesheet" type="text/css" href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print">\n\n\n\n\n\t</head>\n    <body>\n\t\t\n<div id="topbar-container">\n\t<div id="topbar" class="bbs-content">\n\t\t<a id="logo" href="/bbs/">\xe6\x89\xb9\xe8\xb8\xa2\xe8\xb8\xa2\xe5\xaf\xa6\xe6\xa5\xad\xe5\x9d\x8a</a>\n\t\t<span>&rsaquo;</span>\n\t\t<a class="board" href="/bbs/Stock/index.html"><span class="board-label">\xe7\x9c\x8b\xe6\x9d\xbf </span>Stock</a>\n\t\t<a class="right small" href="/about.html">\xe9\x97\x9c\xe6\x96\xbc\xe6\x88\x91\xe5\x80\x91</a>\n\t\t<a class="right small" href="/contact.html">\xe8\x81\xaf\xe7\xb5\xa1\xe8\xb3\x87\xe8\xa8\x8a</a>\n\t</div>\n</div>\n\n<div id="main-container">\n\t<div id="action-bar-container">\n\t\t<div class="action-bar">\n\t\t\t<div class="btn-group btn-group-dir">\n\t\t\t\t<a class="btn selected" href="/bbs/Stock/index.html">\xe7\x9c\x8b\xe6\x9d\xbf</a>\n\t\t\t\t<a class="btn" href="/man/Stock/index.html">\xe7\xb2\xbe\xe8\x8f\xaf\xe5\x8d\x80</a>\n\t\t\t</div>\n\t\t\t<div class="btn-group btn-group-paging">\n\t\t\t\t<a class="btn wide" href="/bbs/Stock/index1.html">\xe6\x9c\x80\xe8\x88\x8a</a>\n\t\t\t\t<a class="btn wide" href="/bbs/Stock/index7731.html">&lsaquo; \xe4\xb8\x8a\xe9\xa0\x81</a>\n\t\t\t\t<a class="btn wide disabled">\xe4\xb8\x8b\xe9\xa0\x81 &rsaquo;</a>\n\t\t\t\t<a class="btn wide" href="/bbs/Stock/index.html">\xe6\x9c\x80\xe6\x96\xb0</a>\n\t\t\t</div>\n\t\t</div>\n\t</div>\n\n\t<div class="r-list-container action-bar-margin bbs-screen">\n\t\t<div class="search-bar">\n\t\t\t<form type="get" action="search" id="search-bar">\n\t\t\t\t<input class="query" type="text" name="q" value="" placeholder="\xe6\x90\x9c\xe5\xb0\x8b\xe6\x96\x87\xe7\xab\xa0&#x22ef;">\n\t\t\t</form>\n\t\t</div>\n\n\t\t\n\t\t\n            \n        \n        \n\t\t<div class="r-ent">\n\t\t\t<div class="nrec"><span class="hl f2">5</span></div>\n\t\t\t<div class="title">\n\t\t\t\n\t\t\t\t<a href="/bbs/Stock/M.1724687691.A.F82.html">[\xe6\x83\x85\xe5\xa0\xb1] 0826 \xe4\xb8\x8a\xe5\xb8\x82\xe6\xab\x83\xe8\x82\xa1\xe7\xa5\xa8\xe9\x80\xb1\xe8\xbd\x89\xe7\x8e\x87\xe6\x8e\x92\xe8\xa1\x8c</a>\n\t\t\t\n\t\t\t</div>\n\t\t\t<div class="meta">\n\t\t\t\t<div class="author">steveisaman</div>\n\t\t\t\t<div class="article-menu">\n\t\t\t\t\t\n\t\t\t\t\t<div class="trigger">&#x22ef;</div>\n\t\t\t\t\t<div class="dropdown">\n\t\t\t\t\t\t<div class="item"><a href="/bbs/Stock/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D&#43;0826&#43;%E4%B8%8A%E5%B8%82%E6%AB%83%E8%82%A1%E7%A5%A8%E9%80%B1%E8%BD%89%E7%8E%87%E6%8E%92%E8%A1%8C">\xe6\x90\x9c\xe5\xb0\x8b\xe5\x90\x8c\xe6\xa8\x99\xe9\xa1\x8c\xe6\x96\x87\xe7\xab\xa0</a></div>\n\t\t\t\t\t\t\n\t\t\t\t\t\t<div class="item"><a href="/bbs/Stock/search?q=author%3Asteveisaman">\xe6\x90\x9c\xe5\xb0\x8b\xe7\x9c\x8b\xe6\x9d\xbf\xe5\x85\xa7 steveisaman \xe7\x9a\x84\xe6\x96\x87\xe7\xab\xa0</a></div>\n\t\t\t\t\t\t\n\t\t\t\t\t</div>\n\t\t\t\t\t\n\t\t\t\t</div>\n\t\t\t\t<div class="date"> 8/26</div>\n\t\t\t\t<div class="mark"></div>\n\t\t\t</div>\n\t\t</div>\n\n\t\t\n            \n        \n        \n\t\t<div class="r-ent">\n\t\t\t<div class="nrec"><span class="hl f2">9</span></div>\n\t\t\t<div class="title">\n\t\t\t\n\t\t\t\t<a href="/bbs/Stock/M.1724692531.A.11C.html">Re: [\xe6\xa8\x99\xe7\x9a\x84] \xe5\x98\x89\ ...

# %%
from bs4 import BeautifulSoup
html_code = BeautifulSoup(data.content)
print(html_code.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    看板 Stock 文章列表 - 批踢踢實業坊
#   </title>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#   <div id="topbar-container">
#    <div class="bbs-content" id="topbar">
#     <a href="/bbs/" id="logo">
#      批踢踢實業坊
#     </a>
#     <span>
#      ›
#     </span>
#     <a class="board" href="/bbs/Stock/index.html">
#      <span class="board-label">
#       看板
#      </span>
#      Stock
#     </a>
#     <a class="right small" href="/about.html">
#      關於我們
#     </a>
#     <a class="right small" href="/contact.html">
#      聯絡資訊
#     </a>
#    </div>
#   </div>
#   <div id="main-container">
#    <div id="action-bar-container">
#     <div class="action-bar">
#      <div class="btn-group btn-group-dir">
#       <a class="btn selected" href="/bbs/Stock/index.html">
#        看板
#       </a>
#       <a class="btn" href="/man/Stock/index.html">
#        精華區
#       </a>
#      </div>
#      <div class="btn-group btn-group-paging">
#       <a class="btn wide" href="/bbs/Stock/index1.html">
#        最舊
#       </a>
#       <a class="btn wide" href="/bbs/Stock/index7731.html">
#        ‹ 上頁
#       </a>
#       <a class="btn wide disabled">
#        下頁 ›
#       </a>
#       <a class="btn wide" href="/bbs/Stock/index.html">
#        最新
#       </a>
#      </div>
#     </div>
#    </div>
#    <div class="r-list-container action-bar-margin bbs-screen">
#     <div class="search-bar">
#      <form action="search" id="search-bar" type="get">
#       <input class="query" name="q" placeholder="搜尋文章⋯" type="text" value=""/>
#      </form>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        5
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Stock/M.1724687691.A.F82.html">
#        [情報] 0826 上市櫃股票週轉率排行
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        steveisaman
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Stock/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+0826+%E4%B8%8A%E5%B8%82%E6%AB%83%E8%82%A1%E7%A5%A8%E9%80%B1%E8%BD%89%E7%8E%87%E6%8E%92%E8%A1%8C">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Stock/search?q=author%3Asteveisaman">
#           搜尋看板內 steveisaman 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        8/26
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        9
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Stock/M.1724692531.A.11C.html">
#        Re: [標的] 嘉實多Castrol買了Gogoro又賣？
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        hyscout
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Stock/search?q=thread%3A%5B%E6%A8%99%E7%9A%84%5D+%E5%98%89%E5%AF%A6%E5%A4%9ACastrol%E8%B2%B7%E4%BA%86Gogoro%E5%8F%88%E8%B3%A3%EF%BC%9F">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Stock/search?q=author%3Ahyscout">
#           搜尋看板內 hyscout 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        8/27
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f0">
#        X1
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Stock/M.1724713955.A.B61.html">
#        [標的] 6244買茂迪開奧迪 當沖多 綠能你不能多
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        c98765432c
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Stock/search?q=thread%3A%5B%E6%A8%99%E7%9A%84%5D+6244%E8%B2%B7%E8%8C%82%E8%BF%AA%E9%96%8B%E5%A5%A7%E8%BF%AA+%E7%95%B6%E6%B2%96%E5%A4%9A+%E7%B6%A0%E8%83%BD%E4%BD%A0%E4%B8%8D%E8%83%BD%E5%A4%9A">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Stock/search?q=author%3Ac98765432c">
#           搜尋看板內 c98765432c 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        8/27
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        24
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Stock/M.1724717876.A.295.html">
#        [新聞] 蘋果宣布9/9舉行秋季新品發表會 主題為「
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        Hamchen
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Stock/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E8%98%8B%E6%9E%9C%E5%AE%A3%E5%B8%839%2F9%E8%88%89%E8%A1%8C%E7%A7%8B%E5%AD%A3%E6%96%B0%E5%93%81%E7%99%BC%E8%A1%A8%E6%9C%83+%E4%B8%BB%E9%A1%8C%E7%82%BA%E3%80%8C">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Stock/search?q=author%3AHamchen">
#           搜尋看板內 Hamchen 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        8/27
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        31
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Stock/M.1724718384.A.BCE.html">
#        [新聞] 傳鄭貞茂將出任台新投信董事長
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        ESandman
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Stock/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E5%82%B3%E9%84%AD%E8%B2%9E%E8%8C%82%E5%B0%87%E5%87%BA%E4%BB%BB%E5%8F%B0%E6%96%B0%E6%8A%95%E4%BF%A1%E8%91%A3%E4%BA%8B%E9%95%B7">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Stock/search?q=author%3AESandman">
#           搜尋看板內 ESandman 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        8/27
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        64
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Stock/M.1724718602.A.F9F.html">
#        [閒聊] 2024/08/27 盤中閒聊
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        laptic
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Stock/search?q=thread%3A%5B%E9%96%92%E8%81%8A%5D+2024%2F08%2F27+%E7%9B%A4%E4%B8%AD%E9%96%92%E8%81%8A">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Stock/search?q=author%3Alaptic">
#           搜尋看板內 laptic 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        8/27
#       </div>
#       <div class="mark">
#        M
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        15
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Stock/M.1724721156.A.D34.html">
#        [新聞] 限貸令釀風暴？房仲曝帶看量驟減 屋主交
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        WinNOKIA
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Stock/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E9%99%90%E8%B2%B8%E4%BB%A4%E9%87%80%E9%A2%A8%E6%9A%B4%EF%BC%9F%E6%88%BF%E4%BB%B2%E6%9B%9D%E5%B8%B6%E7%9C%8B%E9%87%8F%E9%A9%9F%E6%B8%9B+%E5%B1%8B%E4%B8%BB%E4%BA%A4">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Stock/search?q=author%3AWinNOKIA">
#           搜尋看板內 WinNOKIA 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        8/27
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        4
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Stock/M.1724721418.A.361.html">
#        [情報] 美國政府重啟喬治亞州現代電動車廠環評
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        CavendishJr
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Stock/search?q=thread%3A%5B%E6%83%85%E5%A0%B1%5D+%E7%BE%8E%E5%9C%8B%E6%94%BF%E5%BA%9C%E9%87%8D%E5%95%9F%E5%96%AC%E6%B2%BB%E4%BA%9E%E5%B7%9E%E7%8F%BE%E4%BB%A3%E9%9B%BB%E5%8B%95%E8%BB%8A%E5%BB%A0%E7%92%B0%E8%A9%95">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Stock/search?q=author%3ACavendishJr">
#           搜尋看板內 CavendishJr 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        8/27
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f2">
#        5
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Stock/M.1724721436.A.87B.html">
#        [新聞] 注意股:雲豹能源(6869)因近日週轉率過大/
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        August2006
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Stock/search?q=thread%3A%5B%E6%96%B0%E8%81%9E%5D+%E6%B3%A8%E6%84%8F%E8%82%A1%3A%E9%9B%B2%E8%B1%B9%E8%83%BD%E6%BA%90%286869%29%E5%9B%A0%E8%BF%91%E6%97%A5%E9%80%B1%E8%BD%89%E7%8E%87%E9%81%8E%E5%A4%A7%2F">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Stock/search?q=author%3AAugust2006">
#           搜尋看板內 August2006 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        8/27
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#     <div class="r-list-sep">
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#      </div>
#      <div class="title">
#       <a href="/bbs/Stock/M.1719872231.A.9BA.html">
#        [公告] 股票板板規 v4.6 (2024/07/02 修正)
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        rayccccc
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Stock/search?q=thread%3A%5B%E5%85%AC%E5%91%8A%5D+%E8%82%A1%E7%A5%A8%E6%9D%BF%E6%9D%BF%E8%A6%8F+v4.6+%282024%2F07%2F02+%E4%BF%AE%E6%AD%A3%29">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Stock/search?q=author%3Arayccccc">
#           搜尋看板內 rayccccc 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        7/02
#       </div>
#       <div class="mark">
#        !
#       </div>
#      </div>
#     </div>
#     <div class="r-ent">
#      <div class="nrec">
#       <span class="hl f3">
#        99
#       </span>
#      </div>
#      <div class="title">
#       <a href="/bbs/Stock/M.1724718602.A.F9F.html">
#        [閒聊] 2024/08/27 盤中閒聊
#       </a>
#      </div>
#      <div class="meta">
#       <div class="author">
#        laptic
#       </div>
#       <div class="article-menu">
#        <div class="trigger">
#         ⋯
#        </div>
#        <div class="dropdown">
#         <div class="item">
#          <a href="/bbs/Stock/search?q=thread%3A%5B%E9%96%92%E8%81%8A%5D+2024%2F08%2F27+%E7%9B%A4%E4%B8%AD%E9%96%92%E8%81%8A">
#           搜尋同標題文章
#          </a>
#         </div>
#         <div class="item">
#          <a href="/bbs/Stock/search?q=author%3Alaptic">
#           搜尋看板內 laptic 的文章
#          </a>
#         </div>
#        </div>
#       </div>
#       <div class="date">
#        8/27
#       </div>
#       <div class="mark">
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#   </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js">
#   </script>
#   <script src="//images.ptt.cc/bbs/v2.27/bbs.js">
#   </script>
#  </body>
# </html>

# %%
# 語法 bs4.find('標籤') 回傳找到的第一個符合規則的標籤
# 語法 bs4.find('div', id="value") 回傳 id ="value" 的 div 標籤
# 語法 bs4.find('div', class_="r-end") 回傳 class="r-ent" 的 div 標籤
div_list = html_code.find('div', class_="r-ent")


# 找出所有符合規則的元素，以 list 型態儲存
div_list = html_code.find_all('div', class_="r-ent")


# 方法串接
a_tag = html_code.find('div', class_="action-bar").find_all('a')


#讀取標籤的屬性
a_prev_btn = html_code.find('div', class_="action-bar").find_all('a')[3]
a_prev_btn_url = a_prev_btn.attrs['href']
a_prev_btn_text = a_prev_btn.contents[0]


print(a_prev_btn_url, a_prev_btn_text)
# Out:
# /bbs/Stock/index7731.html ‹ 上頁

# %%
# 準備各文章的連結
div_list = html_code.find_all('div', class_="title")


url = []
for div_ in div_list:
  try:
    a_tag = div_.find('a').attrs['href']
    url.append(a_tag)
    print(a_tag)
  except:
    print(None)


print('過濾後的對應文章標籤')
print(url)
# Out:
# /bbs/Stock/M.1724687691.A.F82.html
# /bbs/Stock/M.1724692531.A.11C.html
# /bbs/Stock/M.1724713955.A.B61.html
# /bbs/Stock/M.1724717876.A.295.html
# /bbs/Stock/M.1724718384.A.BCE.html
# /bbs/Stock/M.1724718602.A.F9F.html
# /bbs/Stock/M.1724721156.A.D34.html
# /bbs/Stock/M.1724721418.A.361.html
# /bbs/Stock/M.1724721436.A.87B.html
# /bbs/Stock/M.1719872231.A.9BA.html
# /bbs/Stock/M.1724718602.A.F9F.html
# 過濾後的對應文章標籤
# ['/bbs/Stock/M.1724687691.A.F82.html', '/bbs/Stock/M.1724692531.A.11C.html', '/bbs/Stock/M.1724713955.A.B61.html', '/bbs/Stock/M.1724717876.A.295.html', '/bbs/Stock/M.1724718384.A.BCE.html', '/bbs/Stock/M.1724718602.A.F9F.html', '/bbs/Stock/M.1724721156.A.D34.html', '/bbs/Stock/M.1724721418.A.361.html', '/bbs/Stock/M.1724721436.A.87B.html', '/bbs/Stock/M.1719872231.A.9BA.html', '/bbs/Stock/M.1724718602.A.F9F.html']

# %%
article_url = 'https://www.ptt.cc' + url[0]
page_data = requests.get(article_url, headers=headers)
page_html_code = BeautifulSoup(page_data.content)
print(page_html_code.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <title>
#    [情報] 0826 上市櫃股票週轉率排行 - 看板 Stock - 批踢踢實業坊
#   </title>
#   <meta content="all" name="robots"/>
#   <meta content="Ptt BBS 批踢踢" name="keywords"/>
#   <meta content="上市
# 排行     股票名稱       收盤價   漲跌    漲跌幅  成交量  周轉率
# 1        8028昇陽半     133.50   -5.00   -3.61%  62,057  35.95%
# 2        2402毅嘉       44.10    +0.20   +0.46%  70,584  22.95%
# 3        8039台虹       66.10    +3.90   +6.27%  48,933  20.57%
# " name="description"/>
#   <meta content="Ptt 批踢踢實業坊" property="og:site_name"/>
#   <meta content="[情報] 0826 上市櫃股票週轉率排行" property="og:title"/>
#   <meta content="上市
# 排行     股票名稱       收盤價   漲跌    漲跌幅  成交量  周轉率
# 1        8028昇陽半     133.50   -5.00   -3.61%  62,057  35.95%
# 2        2402毅嘉       44.10    +0.20   +0.46%  70,584  22.95%
# 3        8039台虹       66.10    +3.90   +6.27%  48,933  20.57%
# " property="og:description"/>
#   <link href="https://www.ptt.cc/bbs/Stock/M.1724687691.A.F82.html" rel="canonical"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-common.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-base.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-custom.css" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/pushstream.css" media="screen" rel="stylesheet" type="text/css"/>
#   <link href="//images.ptt.cc/bbs/v2.27/bbs-print.css" media="print" rel="stylesheet" type="text/css"/>
#  </head>
#  <body>
#   <div id="topbar-container">
#    <div class="bbs-content" id="topbar">
#     <a href="/bbs/" id="logo">
#      批踢踢實業坊
#     </a>
#     <span>
#      ›
#     </span>
#     <a class="board" href="/bbs/Stock/index.html">
#      <span class="board-label">
#       看板
#      </span>
#      Stock
#     </a>
#     <a class="right small" href="/about.html">
#      關於我們
#     </a>
#     <a class="right small" href="/contact.html">
#      聯絡資訊
#     </a>
#    </div>
#   </div>
#   <div id="navigation-container">
#    <div class="bbs-content" id="navigation">
#     <a class="board" href="/bbs/Stock/index.html">
#      返回看板
#     </a>
#     <div class="bar">
#     </div>
#    </div>
#   </div>
#   <div id="main-container">
#    <div class="bbs-screen bbs-content" id="main-content">
#     <div class="article-metaline">
#      <span class="article-meta-tag">
#       作者
#      </span>
#      <span class="article-meta-value">
#       steveisaman (who is the man)
#      </span>
#     </div>
#     <div class="article-metaline-right">
#      <span class="article-meta-tag">
#       看板
#      </span>
#      <span class="article-meta-value">
#       Stock
#      </span>
#     </div>
#     <div class="article-metaline">
#      <span class="article-meta-tag">
#       標題
#      </span>
#      <span class="article-meta-value">
#       [情報] 0826 上市櫃股票週轉率排行
#      </span>
#     </div>
#     <div class="article-metaline">
#      <span class="article-meta-tag">
#       時間
#      </span>
#      <span class="article-meta-value">
#       Mon Aug 26 23:54:47 2024
#      </span>
#     </div>
#     上市
#
# 排行     股票名稱       收盤價   漲跌    漲跌幅  成交量  周轉率
#
# 1        8028昇陽半     133.50   -5.00   -3.61%  62,057  35.95%
# 2        2402毅嘉       44.10    +0.20   +0.46%  70,584  22.95%
# 3        8039台虹       66.10    +3.90   +6.27%  48,933  20.57%
# 4        3535晶彩科     75.60    -1.20   -1.56%  15,530  19.65%
# 5        4967十銓       129.00   +10.00  +8.40%  13,582  18.98%
# 6        3047訊舟       41.85    -1.05   -2.45%  28,775  12.94%
# 7        3583辛耘       435.00   -33.50  -7.15%  9,241   11.50%
# 8        9955佳龍       38.10    +1.40   +3.81%  11,647  11.28%
# 9        2467聖         226.50   +4.00   +1.80%  17,385  11.09%
# 10       3450聯鈞       136.50   -5.50   -3.87%  15,932  10.94%
#
# 資料來源：
#     <a href="https://tinyurl.com/yweranfz" rel="noreferrer noopener nofollow" target="_blank">
#      http://tinyurl.com/yweranfz
#     </a>
#     上櫃
#
# 排行     股票名稱       收盤價   漲跌    漲跌幅  成交量  周轉率
#
# 1        5443均豪       134.00   +4.00   +3.08%  91,222  55.24%
# 2        3615安可       32.10    +1.60   +5.25%  28,443  41.54%
# 3        8064東捷       65.80    +0.70   +1.08%  53,907  32.71%
# 4        8096擎亞       54.80    +0.30   +0.55%  42,116  28.20%
# 5        3580友威科     110.50   -2.00   -1.78%  10,149  25.71%
# 6        3073天方能源   94.50    -1.70   -1.77%  7,693   23.96%
# 7        6207雷科       76.80    +1.30   +1.72%  16,366  20.54%
# 8        4561健椿       66.70    +3.70   +5.87%  10,808  18.47%
# 9        6877鏵友益     77.90    +3.30   +4.42%  6,169   16.36%
# 10       3163波若威     161.00   -1.00   -0.62%  12,455  15.46%
#
# 資料來源：
#     <a href="https://tinyurl.com/mahe699z" rel="noreferrer noopener nofollow" target="_blank">
#      http://tinyurl.com/mahe699z
#     </a>
#     何謂股票週轉率?
#
# 來源：
#     <a href="https://tinyurl.com/5n6m3kpv" rel="noreferrer noopener nofollow" target="_blank">
#      http://tinyurl.com/5n6m3kpv
#     </a>
#     原來的外資投信同買排行連結
#
# 來源：
#     <a href="https://tinyurl.com/2wxfc657" rel="noreferrer noopener nofollow" target="_blank">
#      https://tinyurl.com/2wxfc657
#     </a>
#     以上 謝謝
#
# --
#
# "When you live in the right way or you just given everything
#  to whatever you're doing, things happend organically and it's
#  not supposed to make sense but it just happens"
#
#                    LeBron shares his fondest memories of Kobe
#
# --
#     <span class="f2">
#      ※ 發信站: 批踢踢實業坊(ptt.cc), 來自: 36.234.71.51 (臺灣)
#     </span>
#     <span class="f2">
#      ※ 文章網址:
#      <a href="https://www.ptt.cc/bbs/Stock/M.1724687691.A.F82.html" rel="noreferrer noopener nofollow" target="_blank">
#       https://www.ptt.cc/bbs/Stock/M.1724687691.A.F82.html
#      </a>
#     </span>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       TeddyisaBear
#      </span>
#      <span class="f3 push-content">
#       : 感謝分享
#      </span>
#      <span class="push-ipdatetime">
#       08/27 02:26
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       miniminioo
#      </span>
#      <span class="f3 push-content">
#       : 感謝
#      </span>
#      <span class="push-ipdatetime">
#       08/27 03:56
#      </span>
#     </div>
#     <div class="push">
#      <span class="f1 hl push-tag">
#       →
#      </span>
#      <span class="f3 hl push-userid">
#       aika5512308
#      </span>
#      <span class="f3 push-content">
#       : 上櫃又是那幾檔常上榜
#      </span>
#      <span class="push-ipdatetime">
#       08/27 05:16
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       Twilight121
#      </span>
#      <span class="f3 push-content">
#       : 8096繼續往上
#      </span>
#      <span class="push-ipdatetime">
#       08/27 06:23
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       cmuse
#      </span>
#      <span class="f3 push-content">
#       : 今天危險啊
#      </span>
#      <span class="push-ipdatetime">
#       08/27 07:13
#      </span>
#     </div>
#     <div class="push">
#      <span class="hl push-tag">
#       推
#      </span>
#      <span class="f3 hl push-userid">
#       palina
#      </span>
#      <span class="f3 push-content">
#       : 感謝分享
#      </span>
#      <span class="push-ipdatetime">
#       08/27 07:34
#      </span>
#     </div>
#    </div>
#    <div data-longpollurl="/v1/longpoll?id=3df5ba461490630b5f2176d165aaeaee68fff4f6" data-offset="2730" data-pollurl="/poll/Stock/M.1724687691.A.F82.html?cacheKey=2149-686042480&amp;offset=2730&amp;offset-sig=6e54331ee584240b74729091eeddc2f58c16e4d2" id="article-polling">
#    </div>
#   </div>
#   <script async="" src="https://www.googletagmanager.com/gtag/js?id=G-DZ6Y3BY9GW">
#   </script>
#   <script>
#    window.dataLayer = window.dataLayer || [];
#       function gtag(){dataLayer.push(arguments);}
#       gtag('js', new Date());
#
#       gtag('config', 'G-DZ6Y3BY9GW');
#   </script>
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');
#   </script>
#   <script src="//ajax.googleapis.com/ajax/libs/jquery/2.1.1/jquery.min.js">
#   </script>
#   <script src="//images.ptt.cc/bbs/v2.27/bbs.js">
#   </script>
#  </body>
# </html>

# %%
meta_info = page_html_code.find_all('span', class_='article-meta-value')
author = meta_info[0].contents[0]
title = meta_info[2].contents[0]
date = meta_info[3].contents[0]
article = page_html_code.find('div', id = 'main-content').contents[4]
print(author)
print(title)
print(date)
print(article)
# Out:
# steveisaman (who is the man)
# [情報] 0826 上市櫃股票週轉率排行
# Mon Aug 26 23:54:47 2024
#
#
# 上市
#
# 排行     股票名稱       收盤價   漲跌    漲跌幅  成交量  周轉率
#
# 1        8028昇陽半     133.50   -5.00   -3.61%  62,057  35.95%
# 2        2402毅嘉       44.10    +0.20   +0.46%  70,584  22.95%
# 3        8039台虹       66.10    +3.90   +6.27%  48,933  20.57%
# 4        3535晶彩科     75.60    -1.20   -1.56%  15,530  19.65%
# 5        4967十銓       129.00   +10.00  +8.40%  13,582  18.98%
# 6        3047訊舟       41.85    -1.05   -2.45%  28,775  12.94%
# 7        3583辛耘       435.00   -33.50  -7.15%  9,241   11.50%
# 8        9955佳龍       38.10    +1.40   +3.81%  11,647  11.28%
# 9        2467聖         226.50   +4.00   +1.80%  17,385  11.09%
# 10       3450聯鈞       136.50   -5.50   -3.87%  15,932  10.94%
#
# 資料來源：

# %%
import time


ptt_data = []
for url_ in url:
  if url_ != None:
    article_url = 'https://www.ptt.cc' + url_
    page_data = requests.get(article_url, headers=headers)
    page_html_code = BeautifulSoup(page_data.content)
    meta_info = page_html_code.find_all('span', class_='article-meta-value')
    author = meta_info[0].contents[0]
    title = meta_info[2].contents[0]
    date = meta_info[3].contents[0]
    article = page_html_code.find('div', id = 'main-content').contents[4]


    # 建立字典型態
    article_row = {
        'url': article_url,
        'title': title,
        'author': author,
        'date': date,
        'content': article
    }


    # 加入 list 內
    ptt_data.append(article_row)


    print(author, title, date)
    # 暫停
    time.sleep(0.5)


print("完整資料:")
print(ptt_data)
# Out:
# steveisaman (who is the man) [情報] 0826 上市櫃股票週轉率排行 Mon Aug 26 23:54:47 2024
# hyscout (廠廠夠扯了) Re: [標的] 嘉實多Castrol買了Gogoro又賣？ Tue Aug 27 01:15:28 2024
# c98765432c (ccc) [標的] 6244買茂迪開奧迪 當沖多 綠能你不能多 Tue Aug 27 07:12:33 2024
# Hamchen (Ham) [新聞] 蘋果宣布9/9舉行秋季新品發表會 主題為「 Tue Aug 27 08:17:35 2024
# ESandman (打擊...Orz..) [新聞] 傳鄭貞茂將出任台新投信董事長 Tue Aug 27 08:26:18 2024
# laptic (靜夜聖林彼岸花) [閒聊] 2024/08/27 盤中閒聊 Tue Aug 27 08:30:00 2024
# WinNOKIA (海神) [新聞] 限貸令釀風暴？房仲曝帶看量驟減 屋主交 Tue Aug 27 09:12:34 2024
# CavendishJr (梅西務實梅西可愛) [情報] 美國政府重啟喬治亞州現代電動車廠環評 Tue Aug 27 09:16:53 2024
# August2006 (好康 救台灣③下架民進党) [新聞] 注意股:雲豹能源(6869)因近日週轉率過大/ Tue Aug 27 09:17:14 2024
# rayccccc (阿夸哈私奔) [公告] 股票板板規 v4.6 (2024/07/02 修正) Tue Jul  2 06:17:08 2024
# laptic (靜夜聖林彼岸花) [閒聊] 2024/08/27 盤中閒聊 Tue Aug 27 08:30:00 2024
# 完整資料:
# [{'url': 'https://www.ptt.cc/bbs/Stock/M.1724687691.A.F82.html', 'title': '[情報] 0826 上市櫃股票週轉率排行', 'author': 'steveisaman (who is the man)', 'date': 'Mon Aug 26 23:54:47 2024', 'content': '\n\n上市\n\n排行     股票名稱       收盤價   漲跌    漲跌幅  成交量  周轉率\n\n1        8028昇陽半     133.50   -5.00   -3.61%  62,057  35.95%\n2        2402毅嘉       44.10    +0.20   +0.46%  70,584  22.95%\n3        8039台虹       66.10    +3.90   +6.27%  48,933  20.57%\n4        3535晶彩科     75.60    -1.20   -1.56%  15,530  19.65%\n5        4967十銓       129.00   +10.00  +8.40%  13,582  18.98%\n6        3047訊舟       41.85    -1.05   -2.45%  28,775  12.94%\n7        3583辛耘       435.00   -33.50  -7.15%  9,241   11.50%\n8        9955佳龍       38.10    +1.40   +3.81%  11,647  11.28%\n9        2467聖         226.50   +4.00   +1.80%  17,385  11.09%\n10       3450聯鈞       136.50   -5.50   -3.87%  15,932  10.94%\n\n資料來源：'}, {'url': 'https://www.ptt.cc/bbs/Stock/M.1724692531.A.11C.html', 'title': 'Re: [標的] 嘉實多Castrol買了Gogoro又賣？', 'author': 'hyscout (廠廠夠扯了)', 'date': 'Tue Aug 27 01:15:28 2024', 'content': '\n'}, {'url': 'https://www.ptt.cc/bbs/Stock/M.1724713955.A.B61.html', 'title': '[標的] 6244買茂迪開奧迪 當沖多 綠能你不能多', 'author': 'c98765432c (ccc)', 'date': 'Tue Aug 27 07:12:33 2024', 'content': '\n\n標的：6244茂迪\n\n分類：當沖多\n\n分析/正文：\n1.買茂迪開奧迪\n\n2.強如台積電沒有綠能也是枉然\n\n3.太陽能這波殺爛俗到脫褲賠不了太多\n\n4.有底部反轉的氣氛\n\n進退場機制：\n多26-26.3停利+1.5停損-0.5\n\n'}, {'url': 'https://www.ptt.cc/bbs/Stock/M.1724717876.A.295.html', 'title': '[新聞] 蘋果宣布9/9舉行秋季新品發表會 主題為「', 'author': 'Hamchen (Ham)', 'date': 'Tue Aug 27 08:17:35 2024', 'content': "\n\n\n原文標題：蘋果宣布9/9舉行秋季新品發表會 主題為「It's Glowtime」\n\n\n原文連結："}, {'url': 'https://www.ptt.cc/bbs/Stock/M.1724718384.A.BCE.html', 'title': '[新聞] 傳鄭貞茂將出任台新投信董事長', 'author': 'ESandman (打擊...Orz..)', 'date': 'Tue Aug 27 08:26:18 2024', 'content': '\n原文標題：\n\n傳鄭貞茂將出任台新投信董事長\n\n原文連結：\n\n'}, {'url': 'https://www.ptt.cc/bbs/Stock/M.1724718602.A.F9F.html', 'title': '[閒聊] 2024/08/27 盤中閒聊', 'author': 'laptic (靜夜聖林彼岸花)', 'date': 'Tue Aug 27 08:30:00 2024', 'content': '\n==================113/08/27台股資訊重點整理，供股民做投資參考=================\n'}, {'url': 'https://www.ptt.cc/bbs/Stock/M.1724721156.A.D34.html', 'title': '[新聞] 限貸令釀風暴？房仲曝帶看量驟減 屋主交', 'author': 'WinNOKIA (海神)', 'date': 'Tue Aug 27 09:12:34 2024', 'content': '\n原文標題：限貸令釀風暴？房仲曝帶看量驟減 屋主交屋不到半年急脫手\n\n原文連結：'}, {'url': 'https://www.ptt.cc/bbs/Stock/M.1724721418.A.361.html', 'title': '[情報] 美國政府重啟喬治亞州現代電動車廠環評', 'author': 'CavendishJr (梅西務實梅西可愛)', 'date': 'Tue Aug 27 09:16:53 2024', 'content': '\n-------------------------------------------------------------------------\n1.請符合以下文章格式，違者4-1刪除\n2.本分類提供以下幾種文章搬運\n        a. 每日交易數據相關：每日法人買買超、融資券、交易量...\n        b. 公司重要訊息相關：營收、股利、股東會懶人包、法說會內容整理...\n        c. 現有資訊整理相關：殖利率排名、金融股獲利分布、\n3.請詳閱板規參考相關規定\n----------------------------按ctrl+y可刪除以上內容。---------------------\n\n標題：美國政府重啟喬治亞州現代電動車廠環評\n\n來源：韓聯社\n'}, {'url': 'https://www.ptt.cc/bbs/Stock/M.1724721436.A.87B.html', 'title': '[新聞] 注意股:雲豹能源(6869)因近日週轉率過大/', 'author': 'August2006 (好康 救台灣③下架民進党)', 'date': 'Tue Aug 27 09:17:14 2024', 'content': '\n\n注意股:雲豹能源(6869)因近日週轉率過大，今(08/26)日列為注意股\n\n 數報新聞 \u3000 2024/08/26 08:35\n\n\n\n【數報】雲豹能源(6869)因近日週轉率過大，今(08/26)日列為注意股，最新收盤價為252.00元、本益比44.29，列注意股原因為\n\n(第十款)最近六個營業日之累積週轉率為51.50%。且08月23日之週轉率為10.18%\n\n'}, {'url': 'https://www.ptt.cc/bbs/Stock/M.1719872231.A.9BA.html', 'title': '[公告] 股票板板規 v4.6 (2024/07/02 修正)', 'author': 'rayccccc (阿夸哈私奔)', 'date': 'Tue Jul  2 06:17:08 2024', 'content': '\n'}, {'url': 'https://www.ptt.cc/bbs/Stock/M.1724718602.A.F9F.html', 'title': '[閒聊] 2024/08/27 盤中閒聊', 'author': 'laptic (靜夜聖林彼岸花)', 'date': 'Tue Aug 27 08:30:00 2024', 'content': '\n==================113/08/27台股資訊重點整理，供股民做投資參考=================\n'}]

# %%
import pandas
ptt_df = pandas.DataFrame(ptt_data)
ptt_df.to_json()
ptt_df.to_csv()
ptt_df
# Out:
#                                                   url  \
# 0   https://www.ptt.cc/bbs/Stock/M.1724687691.A.F8...
# 1   https://www.ptt.cc/bbs/Stock/M.1724692531.A.11...
# 2   https://www.ptt.cc/bbs/Stock/M.1724713955.A.B6...
# 3   https://www.ptt.cc/bbs/Stock/M.1724717876.A.29...
# 4   https://www.ptt.cc/bbs/Stock/M.1724718384.A.BC...
# 5   https://www.ptt.cc/bbs/Stock/M.1724718602.A.F9...
# 6   https://www.ptt.cc/bbs/Stock/M.1724721156.A.D3...
# 7   https://www.ptt.cc/bbs/Stock/M.1724721418.A.36...
# 8   https://www.ptt.cc/bbs/Stock/M.1724721436.A.87...
# 9   https://www.ptt.cc/bbs/Stock/M.1719872231.A.9B...
# 10  https://www.ptt.cc/bbs/Stock/M.1724718602.A.F9...
#
#                               title                        author  \
# 0              [情報] 0826 上市櫃股票週轉率排行  steveisaman (who is the man)
# 1    Re: [標的] 嘉實多Castrol買了Gogoro又賣？               hyscout (廠廠夠扯了)
# 2        [標的] 6244買茂迪開奧迪 當沖多 綠能你不能多              c98765432c (ccc)
# 3        [新聞] 蘋果宣布9/9舉行秋季新品發表會 主題為「                 Hamchen (Ham)
# 4               [新聞] 傳鄭貞茂將出任台新投信董事長         ESandman (打擊...Orz..)
# 5              [閒聊] 2024/08/27 盤中閒聊              laptic (靜夜聖林彼岸花)
# 6          [新聞] 限貸令釀風暴？房仲曝帶看量驟減 屋主交                 WinNOKIA (海神)
# 7           [情報] 美國政府重啟喬治亞州現代電動車廠環評        CavendishJr (梅西務實梅西可愛)
# 8      [新聞] 注意股:雲豹能源(6869)因近日週轉率過大/     August2006 (好康 救台灣③下架民進党)
# 9   [公告] 股票板板規 v4.6 (2024/07/02 修正)              rayccccc (阿夸哈私奔)
# 10             [閒聊] 2024/08/27 盤中閒聊              laptic (靜夜聖林彼岸花)
#
#                         date  \
# 0   Mon Aug 26 23:54:47 2024
# 1   Tue Aug 27 01:15:28 2024
# 2   Tue Aug 27 07:12:33 2024
# 3   Tue Aug 27 08:17:35 2024
# 4   Tue Aug 27 08:26:18 2024
# 5   Tue Aug 27 08:30:00 2024
# 6   Tue Aug 27 09:12:34 2024
# 7   Tue Aug 27 09:16:53 2024
# 8   Tue Aug 27 09:17:14 2024
# 9   Tue Jul  2 06:17:08 2024
# 10  Tue Aug 27 08:30:00 2024
#
#                                               content
# 0   \n\n上市\n\n排行     股票名稱       收盤價   漲跌    漲跌幅  成...
# 1                                                  \n
# 2   \n\n標的：6244茂迪\n\n分類：當沖多\n\n分析/正文：\n1.買茂迪開奧迪\n\...
# 3   \n\n\n原文標題：蘋果宣布9/9舉行秋季新品發表會 主題為「It's Glowtime」...
# 4              \n原文標題：\n\n傳鄭貞茂將出任台新投信董事長\n\n原文連結：\n\n
# 5   \n==================113/08/27台股資訊重點整理，供股民做投資參考...
# 6         \n原文標題：限貸令釀風暴？房仲曝帶看量驟減 屋主交屋不到半年急脫手\n\n原文連結：
# 7   \n--------------------------------------------...
# 8   \n\n注意股:雲豹能源(6869)因近日週轉率過大，今(08/26)日列為注意股\n\n ...
# 9                                                  \n
# 10  \n==================113/08/27台股資訊重點整理，供股民做投資參考...

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Mounted at /content/gdrive

# %%
ptt_df.to_json('/content/gdrive/My Drive/test/ptt.json')
ptt_df.to_csv('/content/gdrive/My Drive/test/ptt.csv')

# %% [markdown]
# https://www.twse.com.tw/rwd/zh/afterTrading/STOCK_DAY?date=20240821&stockNo=00712&response=json&_=1724204146363

# %%
# URL
stock_query_url = 'https://www.twse.com.tw/rwd/zh/afterTrading/STOCK_DAY?date=20240821&stockNo=00712&response=json&_=1724204146363'


# Query Params 請改成你有興趣的股票代碼
query_date = '20240821'
stock_num = '00712'
response_= 'json'
timestamp_ = '1724204146363'


# Requests Header
headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/127.0.0.0 Safari/537.36'
}


# Target
stock_param_url = stock_query_url.format(query_date, stock_num, response_, timestamp_)


print(stock_param_url)
# Out:
# https://www.twse.com.tw/rwd/zh/afterTrading/STOCK_DAY?date=20240821&stockNo=00712&response=json&_=1724204146363

# %%
import requests
res = requests.get(stock_param_url, verify=False)
res.text
# Out:
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py:1100: InsecureRequestWarning: Unverified HTTPS request is being made to host 'www.twse.com.tw'. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#tls-warnings
#   warnings.warn(
# '{"stat":"OK","date":"20240821","title":"113年08月 00712 復華富時不動產   各日成交資訊","fields":["日期","成交股數","成交金額","開盤價","最高價","最低價","收盤價","漲跌價差","成交筆數"],"data":[["113/08/01","23,060,110","233,272,504","10.15","10.15","10.09","10.12","-0.08","4,961"],["113/08/02","36,545,512","365,377,107","10.02","10.02","9.97","9.97","-0.15","9,392"],["113/08/05","100,459,016","972,197,341","9.85","9.85","9.60","9.68","-0.29","16,394"],["113/08/06","59,416,288","572,940,433","9.58","9.70","9.58","9.65","-0.03","9,407"],["113/08/07","18,202,514","178,141,328","9.73","9.81","9.73","9.80","+0.15","4,541"],["113/08/08","11,952,369","116,655,134","9.77","9.78","9.73","9.75","-0.05","3,655"],["113/08/09","15,249,100","149,356,529","9.85","9.85","9.77","9.79","+0.04","3,389"],["113/08/12","11,912,785","116,853,261","9.80","9.83","9.79","9.83","+0.04","3,031"],["113/08/13","24,888,852","241,580,678","9.72","9.73","9.69","9.72","-0.11","7,415"],["113/08/14","15,451,350","150,292,485","9.74","9.76","9.71","9.73","+0.01","3,788"],["113/08/15","8,766,472","85,625,662","9.75","9.78","9.74","9.78","+0.05","2,561"],["113/08/16","14,312,007","141,290,378","9.85","9.89","9.84","9.89","+0.11","3,343"],["113/08/19","13,115,542","129,243,298","9.92","9.92","9.83","9.85","-0.04","4,252"],["113/08/20","9,207,081","90,793,023","9.87","9.88","9.85","9.87","+0.02","2,347"],["113/08/21","9,007,904","88,366,166","9.82","9.83","9.79","9.83","-0.04","3,009"],["113/08/22","5,821,043","57,216,968","9.85","9.85","9.81","9.84","+0.01","1,763"],["113/08/23","7,185,654","70,482,152","9.80","9.83","9.79","9.83","-0.01","2,232"],["113/08/26","12,184,478","120,483,472","9.90","9.91","9.87","9.91","+0.08","3,139"]],"notes":["符號說明:+/-/X表示漲/跌/不比價","當日統計資訊含一般、零股、盤後定價、鉅額交易，不含拍賣、標購。","ETF證券代號第六碼為K、M、S、C者，表示該ETF以外幣交易。","權證證券代號可重複使用，權證顯示之名稱係目前存續權證之簡稱。"],"total":18}'

# %%
import json
import pandas
stock_data = json.loads(res.text)


# 格式化輸出，方便觀察 (optional)
print(json.dumps(stock_data, sort_keys=False, indent=4, separators=(',', ':'), ensure_ascii=False))
# Out:
# {
#     "stat":"OK",
#     "date":"20240821",
#     "title":"113年08月 00712 復華富時不動產   各日成交資訊",
#     "fields":[
#         "日期",
#         "成交股數",
#         "成交金額",
#         "開盤價",
#         "最高價",
#         "最低價",
#         "收盤價",
#         "漲跌價差",
#         "成交筆數"
#     ],
#     "data":[
#         [
#             "113/08/01",
#             "23,060,110",
#             "233,272,504",
#             "10.15",
#             "10.15",
#             "10.09",
#             "10.12",
#             "-0.08",
#             "4,961"
#         ],
#         [
#             "113/08/02",
#             "36,545,512",
#             "365,377,107",
#             "10.02",
#             "10.02",
#             "9.97",
#             "9.97",
#             "-0.15",
#             "9,392"
#         ],
#         [
#             "113/08/05",
#             "100,459,016",
#             "972,197,341",
#             "9.85",
#             "9.85",
#             "9.60",
#             "9.68",
#             "-0.29",
#             "16,394"
#         ],
#         [
#             "113/08/06",
#             "59,416,288",
#             "572,940,433",
#             "9.58",
#             "9.70",
#             "9.58",
#             "9.65",
#             "-0.03",
#             "9,407"
#         ],
#         [
#             "113/08/07",
#             "18,202,514",
#             "178,141,328",
#             "9.73",
#             "9.81",
#             "9.73",
#             "9.80",
#             "+0.15",
#             "4,541"
#         ],
#         [
#             "113/08/08",
#             "11,952,369",
#             "116,655,134",
#             "9.77",
#             "9.78",
#             "9.73",
#             "9.75",
#             "-0.05",
#             "3,655"
#         ],
#         [
#             "113/08/09",
#             "15,249,100",
#             "149,356,529",
#             "9.85",
#             "9.85",
#             "9.77",
#             "9.79",
#             "+0.04",
#             "3,389"
#         ],
#         [
#             "113/08/12",
#             "11,912,785",
#             "116,853,261",
#             "9.80",
#             "9.83",
#             "9.79",
#             "9.83",
#             "+0.04",
#             "3,031"
#         ],
#         [
#             "113/08/13",
#             "24,888,852",
#             "241,580,678",
#             "9.72",
#             "9.73",
#             "9.69",
#             "9.72",
#             "-0.11",
#             "7,415"
#         ],
#         [
#             "113/08/14",
#             "15,451,350",
#             "150,292,485",
#             "9.74",
#             "9.76",
#             "9.71",
#             "9.73",
#             "+0.01",
#             "3,788"
#         ],
#         [
#             "113/08/15",
#             "8,766,472",
#             "85,625,662",
#             "9.75",
#             "9.78",
#             "9.74",
#             "9.78",
#             "+0.05",
#             "2,561"
#         ],
#         [
#             "113/08/16",
#             "14,312,007",
#             "141,290,378",
#             "9.85",
#             "9.89",
#             "9.84",
#             "9.89",
#             "+0.11",
#             "3,343"
#         ],
#         [
#             "113/08/19",
#             "13,115,542",
#             "129,243,298",
#             "9.92",
#             "9.92",
#             "9.83",
#             "9.85",
#             "-0.04",
#             "4,252"
#         ],
#         [
#             "113/08/20",
#             "9,207,081",
#             "90,793,023",
#             "9.87",
#             "9.88",
#             "9.85",
#             "9.87",
#             "+0.02",
#             "2,347"
#         ],
#         [
#             "113/08/21",
#             "9,007,904",
#             "88,366,166",
#             "9.82",
#             "9.83",
#             "9.79",
#             "9.83",
#             "-0.04",
#             "3,009"
#         ],
#         [
#             "113/08/22",
#             "5,821,043",
#             "57,216,968",
#             "9.85",
#             "9.85",
#             "9.81",
#             "9.84",
#             "+0.01",
#             "1,763"
#         ],
#         [
#             "113/08/23",
#             "7,185,654",
#             "70,482,152",
#             "9.80",
#             "9.83",
#             "9.79",
#             "9.83",
#             "-0.01",
#             "2,232"
#         ],
#         [
#             "113/08/26",
#             "12,184,478",
#             "120,483,472",
#             "9.90",
#             "9.91",
#             "9.87",
#             "9.91",
#             "+0.08",
#             "3,139"
#         ]
#     ],
#     "notes":[
#         "符號說明:+/-/X表示漲/跌/不比價",
#         "當日統計資訊含一般、零股、盤後定價、鉅額交易，不含拍賣、標購。",
#         "ETF證券代號第六碼為K、M、S、C者，表示該ETF以外幣交易。",
#         "權證證券代號可重複使用，權證顯示之名稱係目前存續權證之簡稱。"
#     ],
#     "total":18
# }

# %%
import pandas
stock_df = pandas.DataFrame(stock_data['data'], columns=stock_data['fields'])
stock_df
# Out:
#            日期         成交股數         成交金額    開盤價    最高價    最低價    收盤價   漲跌價差  \
# 0   113/08/01   23,060,110  233,272,504  10.15  10.15  10.09  10.12  -0.08
# 1   113/08/02   36,545,512  365,377,107  10.02  10.02   9.97   9.97  -0.15
# 2   113/08/05  100,459,016  972,197,341   9.85   9.85   9.60   9.68  -0.29
# 3   113/08/06   59,416,288  572,940,433   9.58   9.70   9.58   9.65  -0.03
# 4   113/08/07   18,202,514  178,141,328   9.73   9.81   9.73   9.80  +0.15
# 5   113/08/08   11,952,369  116,655,134   9.77   9.78   9.73   9.75  -0.05
# 6   113/08/09   15,249,100  149,356,529   9.85   9.85   9.77   9.79  +0.04
# 7   113/08/12   11,912,785  116,853,261   9.80   9.83   9.79   9.83  +0.04
# 8   113/08/13   24,888,852  241,580,678   9.72   9.73   9.69   9.72  -0.11
# 9   113/08/14   15,451,350  150,292,485   9.74   9.76   9.71   9.73  +0.01
# 10  113/08/15    8,766,472   85,625,662   9.75   9.78   9.74   9.78  +0.05
# 11  113/08/16   14,312,007  141,290,378   9.85   9.89   9.84   9.89  +0.11
# 12  113/08/19   13,115,542  129,243,298   9.92   9.92   9.83   9.85  -0.04
# 13  113/08/20    9,207,081   90,793,023   9.87   9.88   9.85   9.87  +0.02
# 14  113/08/21    9,007,904   88,366,166   9.82   9.83   9.79   9.83  -0.04
# 15  113/08/22    5,821,043   57,216,968   9.85   9.85   9.81   9.84  +0.01
# 16  113/08/23    7,185,654   70,482,152   9.80   9.83   9.79   9.83  -0.01
# 17  113/08/26   12,184,478  120,483,472   9.90   9.91   9.87   9.91  +0.08
#
#       成交筆數
# 0    4,961
# 1    9,392
# 2   16,394
# 3    9,407
# 4    4,541
# 5    3,655
# 6    3,389
# 7    3,031
# 8    7,415
# 9    3,788
# 10   2,561
# 11   3,343
# 12   4,252
# 13   2,347
# 14   3,009
# 15   1,763
# 16   2,232
# 17   3,139

# %%
# 計算平均值
means_ = pandas.to_numeric(stock_df['開盤價']).mean()
print("平均開盤價:", means_)


#計算平均值: 資料帶有格式化輸出
mean_total = pandas.to_numeric(stock_df['成交股數'].str.replace(',','').astype(int)).mean()
print("平均交易股數:", mean_total)
# Out:
# 平均開盤價: 9.831666666666667
# 平均交易股數: 22041004.277777776

# %%
# 安裝套件
# !pip install scikit-learn
# !pip install joblib
# Out:
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (1.3.2)
# Requirement already satisfied: numpy<2.0,>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.5.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn) (3.5.0)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (1.4.2)

# %%
# 建立訓練資料
print("擷取 dataframe 第三列資料作為訓練資料:")
x = stock_df.iloc[:,3].values
print(x)
print("陣列大小:",len(x))
print("============================")


# 刪除最後一格元素
print("移除最後一個元素:")
x = stock_df.iloc[:,3].drop(13, inplace=False, axis=0).values
print(x)
print("陣列大小:",len(x))
print("============================")


#重新排列
print("轉置矩陣:")
x = stock_df.iloc[:,3].drop(13, inplace=False, axis=0).values.reshape(-1, 1)
print(x)
print("陣列大小:",len(x))

# %%
y = stock_df.iloc[:,6].values


y=stock_df.iloc[:,6].drop(0, inplace=False, axis=0).values


print(y)

# %%
# 載入 scikit learn 機器學習套件
from sklearn.linear_model import LinearRegression


# 初始化 model
lr = LinearRegression()


#用資料集訓練模型
lr.fit(x, y)

# %%
from sklearn.linear_model import LinearRegression

# 假設這是你的訓練資料
X_train = [[1], [2], [3], [4], [5]]
y_train = [1, 2, 3, 4, 5]

# 創建並訓練線性回歸模型
lr = LinearRegression()
lr.fit(X_train, y_train)

# 建立測試資料
x_test =[
    [10.21],
    [9.8],
    [9.9]
]


# 用模型預測資料
y_test  = lr.predict(x_test)


# 印出預測結果
print(y_test)
# Out:
# [10.21  9.8   9.9 ]

# %%
# 保存模型 (一)
from google.colab import drive
import joblib


# 掛載 Google Drive
drive.mount('/content/gdrive', force_remount=True)


# 將整個模型儲存成 joblib 格式的檔案 改成自己的路徑位置
joblib.dump(lr, '/content/gdrive/My Drive/test/lr_model20240821.pkl')
# Out:
# Mounted at /content/gdrive
# ['/content/gdrive/My Drive/test/lr_model20240821.pkl']

# %%
# 保存模型 (二)
import pickle
from google.colab import drive

# 掛載 Google Drive
drive.mount('/content/gdrive')

# 用 pickle
filename = "/content/gdrive/My Drive/test/lr_model20240821.pkl"
pickle.dump(lr, open(filename, 'wb'))

# %%
from sklearn.linear_model import LinearRegression
from time import time
import pickle
import _pickle as cPickle
import joblib
import os

print("Joblib 載入 Pickle 檔案:")
t1 = time()
lr_model_lib = joblib.load('/content/gdrive/My Drive/test/lr_model20240821.pkl')
print("Joblib module 載入時間:", time() - t1)
print("Joblib module file size", os.path.getsize('/content/gdrive/My Drive/test/lr_model20240821.pkl'), "kB \n")

print("Joblib 載入 Joblib 檔案:")
t1 = time()
lr_model_lib = joblib.load('/content/gdrive/My Drive/test/lr_model20240821')
print("Joblib module 載入時間:", time() - t1)
print("Joblib module file size", os.path.getsize('/content/gdrive/My Drive/test/lr_model20240821'), "kB \n")

print("==================================\n")

# print("Pickle 載入 Joblib 檔案:\n")
# t1 = time()
# lr_model_pkl =  pickle.load(open('/content/gdrive/My Drive/test/lr_model20240821', 'rb'))
# print("Pickle module 載入時間:", time() - t1)
# print("Pickle module file size", os.path.getsize('/content/gdrive/My Drive/test/lr_model20240821'), "kB \n")

print("Pickle 載入 Pickle 檔案:")
t1 = time()
lr_model_pkl =  pickle.load(open('/content/gdrive/My Drive/test/lr_model20240821.pkl', 'rb'))
print("Pickle module 載入時間:", time() - t1)
print("Pickle module file size", os.path.getsize('/content/gdrive/My Drive/test/lr_model20240821.pkl'), "kB \n")
print("==================================\n")

# print("cPickle 載入 Joblib 檔案:\n")
# t1 = time()
# lr_model_pkl =  cPickle.load(open('/content/gdrive/My Drive/test/lr_model20240821', 'rb'))
# print("Pickle module 載入時間:", time() - t1)
# print("Pickle module file size", os.path.getsize('/content/gdrive/My Drive/test/lr_model20240821'), "kB \n")
# print(time() - t1)

print("cPickle 載入 Pickle 檔案:")
t1 = time()
lr_model_pkl =  cPickle.load(open('/content/gdrive/My Drive/test/lr_model20240821.pkl', 'rb'))
print("cPickle module 載入時間:", time() - t1)
print("cPickle module file size", os.path.getsize('/content/gdrive/My Drive/test/lr_model20240821.pkl'), "kB \n")
# Out:
# Joblib 載入 Pickle 檔案:
# Joblib module 載入時間: 0.004059553146362305
# Joblib module file size 146 kB
#
# Joblib 載入 Joblib 檔案:
# Joblib module 載入時間: 0.005846977233886719
# Joblib module file size 560 kB
#
# ==================================
#
# Pickle 載入 Pickle 檔案:
# Pickle module 載入時間: 0.004215240478515625
# Pickle module file size 146 kB
#
# ==================================
#
# cPickle 載入 Pickle 檔案:
# cPickle module 載入時間: 0.005613088607788086
# cPickle module file size 146 kB

# %%
import os
print(os.listdir('/content/gdrive/My Drive/test'))
# Out:
# ['ptt.json', 'ptt.csv', 'ptt2.json', 'ptt2.csv', 'lr_model20240821', '爬蟲.ipynb', '.ipynb_checkpoints']

# %%
import requests
line_url = 'https://notify-api.line.me/api/notify'
line_token = ''
line_token_with_h = "Bearer {}".format(line_token)

header_line = {
    'Authorization': line_token_with_h
}

line_notify_message = {
    'message': ' ',
    'stickerPackageId': 446,
    'stickerId': 1988
}

res = requests.post(line_url, headers=header_line, data = line_notify_message)
res_msg = json.loads(res.text)
print("[{}] {}".format(res_msg['status'], res_msg['message']))
# Out:
# [200] ok
